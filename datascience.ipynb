# %%
import gzip
import pandas as pd
import csv
f = gzip.open("t.json.gz", mode='rt')
csvobj = csv.reader(f,delimiter = ',',quotechar="'")

# %%
csvobj

# %%
df=pd.DataFrame(csvobj)

# %%
df
# Out:
#                                   0                          1   \
# 0           {"category": "Household"   "crawl_date": "20180727"
# 1           {"category": "Household"   "crawl_date": "20180727"
# 2           {"category": "Household"   "crawl_date": "20180727"
# 3           {"category": "Household"   "crawl_date": "20180727"
# 4           {"category": "Household"   "crawl_date": "20180727"
# 5           {"category": "Household"   "crawl_date": "20180727"
# 6           {"category": "Household"   "crawl_date": "20180727"
# 7           {"category": "Household"   "crawl_date": "20180727"
# 8           {"category": "Household"   "crawl_date": "20180727"
# 9           {"category": "Household"   "crawl_date": "20180727"
# 10          {"category": "Household"   "crawl_date": "20180727"
# 11          {"category": "Household"   "crawl_date": "20180727"
# 12          {"category": "Household"   "crawl_date": "20180727"
# 13          {"category": "Household"   "crawl_date": "20180727"
# ...

# %%
len(df)
# Out:
# 142291

# %%
import gzip
import csv
f = gzip.open("y.json.gz", mode='rt')
csvobj1 = csv.reader(f,delimiter = ',',quotechar="'")

# %%
df1=pd.DataFrame(csvobj1)

# %%
ind = df1[5].isin(df[5]) & df[5].isin(df1[5])

# %%
df[ind==True]
# Out:
#                                   0                          1   \
# 0           {"category": "Household"   "crawl_date": "20180727"
# 1           {"category": "Household"   "crawl_date": "20180727"
# 2           {"category": "Household"   "crawl_date": "20180727"
# 3           {"category": "Household"   "crawl_date": "20180727"
# 4           {"category": "Household"   "crawl_date": "20180727"
# 5           {"category": "Household"   "crawl_date": "20180727"
# 6           {"category": "Household"   "crawl_date": "20180727"
# 7           {"category": "Household"   "crawl_date": "20180727"
# 8           {"category": "Household"   "crawl_date": "20180727"
# 9           {"category": "Household"   "crawl_date": "20180727"
# 10          {"category": "Household"   "crawl_date": "20180727"
# 11          {"category": "Household"   "crawl_date": "20180727"
# 12          {"category": "Household"   "crawl_date": "20180727"
# 13          {"category": "Household"   "crawl_date": "20180727"
# ...

# %%
len(df[ind==True]) #no of urls overlaping
# Out:
# 138919

# %%
a=[]
def unique(list1): 
      
 
    list_set = set(list1) 
     
    unique_list = (list(list_set)) 
    for x in unique_list: 
        a.append(x)
    return a

# %%
c=unique(df[0])

# %%
d=unique(df1[0])

# %%
c==d
# Out:
# True

# %%
len(c)#unique categories in both file
# Out:
# 100

# %%
ind1 = df1[0].isin(df[0]) & df[0].isin(df1[0])

# %%
df[ind1==False][0].unique()#list of categories which is not overlapping
# Out:
# array(['{"category": "Personal Care"'], dtype=object)

# %%
x=df[ind==True]

# %%
y=df1[ind==True]
# Out:
# C:\Users\nivedidha\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
z=x[8]-y[8]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ...

# %%
## z=x[8]-y[8]
